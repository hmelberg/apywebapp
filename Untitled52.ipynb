# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]}

df = pd.DataFrame(data)

df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
fig=df.plot.bar()

fig
# Out:
# <Axes: >

# %% [markdown]
# Here is some text.
# # a headline
# And a list of fruits:
# - apple

# %% [markdown]
# We can make an equation appear centered on a new line, like
#
# \begin{align}
#         \mathbf{a} \cdot \mathbf{b} = \sum_{i=1}^n a_i b_i.
#     \end{align}

# %% [markdown]
# ![7fnWtKsXBmk= (1).png](data:image/png;base64,...)

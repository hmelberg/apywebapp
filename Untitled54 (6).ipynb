# %% [markdown]
# # This is a title
# Here is some markdown
#
# ::: accordion
# A title
#
# And some text
# :::
#
# What about math?
# @e=mc^2@

# %%
import pandas as pd
s=pd.Series([2,6,4])
s.plot()
# Out:
# <Axes: >

# %%
#%%cell
import pandas as pd
s=pd.Series([2,6,4])
s.plot()
# Out:
# <Axes: >

# %%
#nb.display_output
s.plot.bar()
# Out:
# <Axes: >

# %%
#%%cell(use_stored_output=True)
import pandas as pd
s=pd.Series([2,6,4,3,5])
s.plot()
# Out:
# <Axes: >
